# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# histopgram grafiği

# %%
import seaborn as sns 
diamonds=sns.load_dataset("diamonds")

df=diamonds.copy()
df.head
# Out:
# <bound method NDFrame.head of        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# ...

# %%
#distplot sns içerisinden kaldırılmış. onun yerine displot /histplot ve kdeplot kullanabiliriz.
#displot: hem histogram hem KDE(kernel density estimate)
#histplot: sadece histogram 
#kdeplot:sadece KDE
sns.displot(df.price, kde=False); 
#bins ekleleyebiliriz. (aralık)

sns.displot(df.price, bins=100,kde=False);
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# ?sns.displot
# Out:
# Signature:
# sns.displot(
#     data=None,
#     *,
#     x=None,
#     y=None,
#     hue=None,
#     row=None,
#     col=None,
#     weights=None,
#     kind='hist',
#     rug=False,
#     rug_kws=None,
#     log_scale=None,
#     legend=True,
#     palette=None,
#     hue_order=None,
#     hue_norm=None,
#     color=None,
#     col_wrap=None,
#     row_order=None,
#     col_order=None,
#     height=5,
#     aspect=1,
#     facet_kws=None,
#     **kwargs,
# )
# Docstring:
# Figure-level interface for drawing distribution plots onto a FacetGrid.
#
# This function provides access to several approaches for visualizing the
# univariate or bivariate distribution of data, including subsets of data
# defined by semantic mapping and faceting across multiple subplots. The
# ``kind`` parameter selects the approach to use:
#
# - :func:`histplot` (with ``kind="hist"``; the default)
# - :func:`kdeplot` (with ``kind="kde"``)
# - :func:`ecdfplot` (with ``kind="ecdf"``; univariate-only)
#
# ...

# %%
sns.displot(df.price, kde=True); # kde true dersek  yoğunluğu ekliyor ve y ekseni 0-1 aralığnda yoğunluğa göre değişiyor
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(df.price) #sadece histogram
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='price', ylabel='Count'>

# %%
# ?sns.histplot
# Out:
# Signature:
# sns.histplot(
#     data=None,
#     *,
#     x=None,
#     y=None,
#     hue=None,
#     weights=None,
#     stat='count',
#     bins='auto',
#     binwidth=None,
#     binrange=None,
#     discrete=None,
#     cumulative=False,
#     common_bins=True,
#     common_norm=True,
#     multiple='layer',
#     element='bars',
#     fill=True,
#     shrink=1,
#     kde=False,
#     kde_kws=None,
#     line_kws=None,
#     thresh=0,
#     pthresh=None,
#     pmax=None,
#     cbar=False,
#     cbar_ax=None,
#     cbar_kws=None,
#     palette=None,
#     hue_order=None,
#     hue_norm=None,
#     color=None,
#     log_scale=None,
#     legend=True,
#     ax=None,
#     **kwargs,
# )
# Docstring:
# Plot univariate or bivariate histograms to show distributions of datasets.
#
# A histogram is a classic visualization tool that represents the distribution
# of one or more variables by counting the number of observations that fall within
# discrete bins.
#
# ...

# %%
sns.histplot(df.price)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.kdeplot(df.price, fill=True); #sadece yoğunluk. fill=True dedik ve altını da doldurduk
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# grafiğini geliştirelim 
g=sns.FacetGrid(diamonds, hue="cut")
g.map(sns.histplot,"price"); # hue=cut dersek alt kategorileri iç içe ekler ancak col=cut dersek ayrı ayrı xy eksenleri çizer

(sns.FacetGrid(df,
              hue="cut")).map(sns.histplot,
    "price")
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
(sns.FacetGrid(df, 
               hue="cut",
              height=10 #eksen yüksekliği
              )).map(sns.histplot, "price" )
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
(sns.FacetGrid(df, 
               hue="cut",
              height=5 ,#eksen yüksekliği
               xlim=(0,10000) #x eksen aralığı
              )).map(sns.histplot, "price" ).add_legend(); #add_legend diyerek alt grupların açıklamalarını ekledik
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
#yukarıdakinin aynısını kde için yapalım 
(sns.FacetGrid(df, 
               hue="cut",
              height=5 ,#eksen yüksekliği
               xlim=(0,10000) #x eksen aralığı
              )).map(sns.kdeplot, "price" , shade=True).add_legend(); #add_legend diyerek alt grupların açıklamalarını ekledik
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# ...

# %%
import seaborn as sns 
tips=sns.load_dataset("tips")
df=tips.copy()
df.head()
df.describe().T
# Out:
#             count       mean       std   min      25%     50%      75%    max
# total_bill  244.0  19.785943  8.902412  3.07  13.3475  17.795  24.1275  50.81
# tip         244.0   2.998279  1.383638  1.00   2.0000   2.900   3.5625  10.00
# size        244.0   2.569672  0.951100  1.00   2.0000   2.000   3.0000   6.00

# %%
df["sex"].value_counts() #kategorik değişkenin sayılarına baktık.
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df["smoker"].value_counts() #kategorik değişkenin sayılarına baktık.
# Out:
# smoker
# No     151
# Yes     93
# Name: count, dtype: int64

# %%
df["day"].value_counts() #kategorik değişkenin sayılarına baktık.
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
df["time"].value_counts() #kategorik değişkenin sayılarına baktık.
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
sns.boxplot(x=df["total_bill"]);

# %%
sns.boxplot(x=df["total_bill"], orient="v"); #dikey formatta kullanmak için orient=v kullanılır.
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1599: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %%
sns.boxplot(x="day", y="total_bill", data=df )
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
pip install --upgrade seaborn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 7.1 MB/s eta 0:00:00ta 0:00:01
# ...
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.12.2
#     Uninstalling seaborn-0.12.2:
#       Successfully uninstalled seaborn-0.12.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ydata-profiling 4.6.4 requires numpy<1.26,>=1.16.0, but you have numpy 1.26.4 which is incompatible.
# ydata-profiling 4.6.4 requires seaborn<0.13,>=0.10.1, but you have seaborn 0.13.2 which is incompatible.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
sns.catplot(y="total_bill", kind="violin", data=df); #violin grafiği catplot içinde oluşturulur.

# %%
sns.catplot(x="day", y="total_bill", kind="violin", hue="sex", data=df);
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# /opt/conda/lib/python3.10/site-packages/seaborn/categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
sns.scatterplot(x="total_bill", y="tip", data=df); #scatterplot 2 sayısal değişken arasındaki korelasyonu bize verir.yukarıdakiler hep tek değişkenliydi ancak artık 2li değişkenlerle çalışacağız.

# %%
sns.scatterplot(x="total_bill", y="tip", hue="time", data=df); #boyut olarak kategorik bir değişken ekledik.

# %%
sns.scatterplot(x="total_bill", y="tip", hue="time", style="time", data=df);

# %%
sns.scatterplot(x="total_bill", y="tip", hue="day", style="time", data=df);

# %%
sns.scatterplot(x="total_bill", y="tip", hue="size", style="size", data=df); #boyuta sürekli bir değişken de ekleyebiliriz.

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
sns.lmplot(x="total_bill", y="tip", data=df); #yukarıda sadece nokta grafiğini kullandık korelasyon için.
#şimdi ise çizgi grafiğini kullanacağız. lmplot: lineer model demek. doğrusal çizgi sağlar

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker" , data=df);

# %%
sns.lmplot(x="total_bill", y="tip", hue="smoker" , col="time", row="sex", data=df);

# %%
iris=sns.load_dataset("iris")
df=iris.copy()
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.dtypes # species aralarında kademe farklı olmadığu için object olarak kalabilir kategori yapmaya gerek yok.
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
sns.pairplot(df); #pairplot birden fazla grafiği içerir: scatterplot, diyagonal (histogram veya kde)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.pairplot(df, hue="species"); # boyut ekleyelim
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
sns.pairplot(df, hue="species", markers=["o", "s", "D"]);
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
sns.pairplot(df, kind="reg", hue="species");
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
flights=sns.load_dataset("flights")
df=flights.copy()
df.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
#headmap kullanmadan önce pivot tablo haline getirmemiz gerekiyor. 

df=df.pivot(index="month", columns="year", values="passengers");
df.head()
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472

# %%
sns.heatmap(df); # açık olanlar daha yüksek sayılara sahip. yıllar geçtikçe uçuşların arttığını görebiliriz.

# %%
sns.heatmap(df, annot=True, fmt="d", cmap="YlGnBu", linewidths=.5); # annot true: hücredeki değerlerin gösterilmesini sağlar. fmt=d: değerlerin tam sayı formatında gösterilmesini sağlar .
#cmap=ylgn: renk paletini belirler
# linewidths : aralarına çizgi koyar

# %%
fmri=sns.load_dataset("fmri")
df=fmri.copy()
df.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.lineplot(x="timepoint", y="signal", hue="event", data=df);
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %%
# !pip install pandas_datareader
import pandas_datareader.data as web
import datetime
start=datetime.datetime(2016,1,1)
end=datetime.datetime(2019,8,25)

# %%
df=web.get_data_yahoo("AAPL", start=start, end=end) #apple hissesini çektik
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 df=web.get_data_yahoo("AAPL", start=start, end=end) #apple hissesini çektik
#       2 df.head()
#
# File /opt/conda/lib/python3.10/site-packages/pandas_datareader/data.py:80, in get_data_yahoo(*args, **kwargs)
#      79 def get_data_yahoo(*args, **kwargs):
# ---> 80     return YahooDailyReader(*args, **kwargs).read()
#
# File /opt/conda/lib/python3.10/site-packages/pandas_datareader/base.py:253, in _DailyBaseReader.read(self)
#     251 # If a single symbol, (e.g., 'GOOG')
#     252 if isinstance(self.symbols, (string_types, int)):
# --> 253     df = self._read_one_data(self.url, params=self._get_params(self.symbols))
#     254 # Or multiple symbols, (e.g., ['GOOG', 'AAPL', 'MSFT'])
#     255 elif isinstance(self.symbols, DataFrame):
#
# ...
